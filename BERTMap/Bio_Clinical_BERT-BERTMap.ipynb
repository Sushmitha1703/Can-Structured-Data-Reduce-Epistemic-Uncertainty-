# %%
# !pip install deeponto

# %%
from deeponto.onto import Ontology
# Out:
# Please enter the maximum memory located to JVM [8g]: 8g

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
src_onto = Ontology("symp.owl")
tgt_onto = Ontology("CSSO_ver0.6.owl")

# %%
print(src_onto.owl_annotation_properties)
# Out:
# {'http://purl.obolibrary.org/obo/IAO_0000115': <java object 'uk.ac.manchester.cs.owl.owlapi.OWLAnnotationPropertyImpl'>, 'http://purl.obolibrary.org/obo/IAO_0000700': <java object 'uk.ac.manchester.cs.owl.owlapi.OWLAnnotationPropertyImpl'>, 'http://purl.obolibrary.org/obo/IAO_0100001': <java object 'uk.ac.manchester.cs.owl.owlapi.OWLAnnotationPropertyImpl'>, 'http://purl.org/dc/elements/1.1/description': <java object 'uk.ac.manchester.cs.owl.owlapi.OWLAnnotationPropertyImpl'>, 'http://purl.org/dc/elements/1.1/title': <java object 'uk.ac.manchester.cs.owl.owlapi.OWLAnnotationPropertyImpl'>, 'http://purl.org/dc/terms/license': <java object 'uk.ac.manchester.cs.owl.owlapi.OWLAnnotationPropertyImpl'>, 'http://www.geneontology.org/formats/oboInOwl#auto-generated-by': <java object 'uk.ac.manchester.cs.owl.owlapi.OWLAnnotationPropertyImpl'>, 'http://www.geneontology.org/formats/oboInOwl#created_by': <java object 'uk.ac.manchester.cs.owl.owlapi.OWLAnnotationPropertyImpl'>, 'http://www.geneon
# ...

# %%
print(tgt_onto.owl_annotation_properties)
# Out:
# {'http://purl.org/dc/elements/1.1/creator': <java object 'uk.ac.manchester.cs.owl.owlapi.OWLAnnotationPropertyImpl'>, 'http://purl.org/dc/elements/1.1/date': <java object 'uk.ac.manchester.cs.owl.owlapi.OWLAnnotationPropertyImpl'>, 'http://purl.org/dc/elements/1.1/description': <java object 'uk.ac.manchester.cs.owl.owlapi.OWLAnnotationPropertyImpl'>, 'http://purl.org/dc/elements/1.1/title': <java object 'uk.ac.manchester.cs.owl.owlapi.OWLAnnotationPropertyImpl'>, 'http://www.w3.org/2000/01/rdf-schema#comment': <java object 'uk.ac.manchester.cs.owl.owlapi.OWLAnnotationPropertyImpl'>, 'http://www.w3.org/2000/01/rdf-schema#isDefinedBy': <java object 'uk.ac.manchester.cs.owl.owlapi.OWLAnnotationPropertyImpl'>, 'http://www.w3.org/2000/01/rdf-schema#label': <java object 'uk.ac.manchester.cs.owl.owlapi.OWLAnnotationPropertyImpl'>, 'http://www.w3.org/2000/01/rdf-schema#seeAlso': <java object 'uk.ac.manchester.cs.owl.owlapi.OWLAnnotationPropertyImpl'>, 'http://www.w3.org/2002/07/owl#deprecate
# ...

# %%
from deeponto.align.bertmap import BERTMapPipeline, DEFAULT_CONFIG_FILE

# %%
config = BERTMapPipeline.load_bertmap_config(f"/content/config_bertmap.yaml")

config.model = "bertmap"
config.bert.resume_training = None
config.bert.resume_from_checkpoint = None

bertmap = BERTMapPipeline(src_onto, tgt_onto, config)
# Out:
# [Time: 00:00:00] - [PID: 16491] - [Model: bertmap]
# Load the following configurations:
# {
#     "model": "bertmap",
#     "output_path": "/content",
#     "annotation_property_iris": [
#         "http://purl.obolibrary.org/obo/IAO_000011",
#         "http://purl.obolibrary.org/obo/IAO_0000119",
#         "http://purl.obolibrary.org/obo/IAO_0000700",
#         "http://purl.obolibrary.org/obo/OBI_9991118",
#         "http://purl.obolibrary.org/obo/doid#DO_AGR_slim",
#         "http://purl.obolibrary.org/obo/doid#DO_CFDE_slim",
#         "http://purl.obolibrary.org/obo/doid#DO_FlyBase_slim",
#         "http://purl.obolibrary.org/obo/doid#DO_GXD_slim",
#         "http://purl.obolibrary.org/obo/doid#DO_IEDB_slim",
#         "http://purl.obolibrary.org/obo/doid#DO_MGI_slim",
#         "http://purl.obolibrary.org/obo/doid#DO_RAD_slim",
#         "https://github.com/DiseaseOntology/HumanDiseaseOntology#DO_cancer_slim",
#         "http://purl.obolibrary.org/obo/doid#DO_rare_slim",
# ...

# %%
test_cands_file = f"content/refs_equiv/test.cands.tsv"

# %%
# !cp -r /content/bertmap /content/drive/MyDrive
